# %%
# Setup 
import time
import h5py
import numpy as np
import matplotlib.pyplot as plt
import hdf5_generator 
from cs231n.classifiers.fc_net import *
from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.solver import Solver


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
# Load images and store in HDF5 format
DATA_FILENAME = "dataset/fer2013/fer2013.csv"
hdf5_generator.generate(DATA_FILENAME)

# %%
#Load image data from hdf5 file
data = {}

h5f = h5py.File('../dataset/data.h5','r')
data['X_train'] = h5f['X_train'][:]
data['X_test'] = h5f['X_test'][:]
data['X_val'] = h5f['X_val'][:]
data['y_train'] = h5f['y_train'][:].astype(np.int64)
data['y_val'] = h5f['y_val'][:].astype(np.int64)
data['y_test'] = h5f['y_test'][:].astype(np.int64)

# Print data size and shape
for k, v in data.iteritems():
  print '%s: ' % k, v.shape, v.dtype
# Out:
# X_test:  (3589, 48, 48) float64
# X_train:  (28709, 48, 48) float64
# X_val:  (3589, 48, 48) float64
# y_val:  (3589,) int64
# y_train:  (28709,) int64
# y_test:  (3589,) int64

# %%
# Train a convnet using raw pixel features
from cs231n.classifiers.convnet import *
from cs231n.layers import *
from cs231n.fast_layers import *

# Normalize the data: subtract the mean image
mean_image = np.mean(data['X_train'])
data['X_train'] -= mean_image
data['X_val'] -= mean_image
data['X_test'] -= mean_image

data['X_train'] = data['X_train'].reshape([data['X_train'].shape[0], 48, 48, 1]).transpose(0,3,1,2)
data['X_val'] = data['X_val'].reshape([data['X_val'].shape[0], 48, 48, 1]).transpose(0,3,1,2)
data['X_test'] = data['X_test'].reshape([data['X_test'].shape[0], 48, 48, 1]).transpose(0,3,1,2)

data['y_train'] = data['y_train'].astype(np.int64)
data['y_val'] = data['y_val'].astype(np.int64)
data['y_test'] = data['y_test'].astype(np.int64)


convlayer_params = {'convlayer_num': 2 ,'num_filters': [32, 32], 'filter_size': 3,
                   'stride': 1, 'pad':(3 - 1) / 2, 's_batch_norm': False,
                   'pool_dim': 2, 'pool_stride': 2}
affinelayer_params = {'afflayer_num': 1, 'hidden_dim': [50], 'batch_norm': False,
                      'dropout': False}

print 'check initial loss:'
###Loss check###
weight_scales = 5e-2
model = MyFullyConvNet(convlayer_params, affinelayer_params, weight_scale=weight_scales, reg=0.0)

X = np.random.randn(100, 1, 48, 48)
y = np.random.randint(7, size=100)
loss, _ = model.loss(X, y)

# Sanity check: Loss should be about log(7) = 1.945
print 'Sanity check: Initial loss (no regularization): ', loss

# Sanity check: Loss should increase when we add regularization
model = MyFullyConvNet(convlayer_params, affinelayer_params, weight_scale=weight_scales, reg=0.01)
loss, _ = model.loss(X, y)
print 'Sanity check: Initial loss (with regularization): ', loss
print ' '
print 'check gradient:'

###Gradient check using numerical gradient computatation###
num_inputs = 2
input_shape = (1, 16, 16)
reg = 0.0
num_classes = 7
X = np.random.randn(num_inputs, *input_shape)
y = np.random.randint(num_classes, size=num_inputs)

convlayer_params = {'convlayer_num': 2 ,'num_filters': [3, 3], 'filter_size': 3,
                   'stride': 1, 'pad':(3 - 1) / 2, 's_batch_norm': False,
                   'pool_dim': 2, 'pool_stride': 2}

affinelayer_params = {'afflayer_num': 1, 'hidden_dim': [7], 'batch_norm': False,
                      'dropout': False}

model = MyFullyConvNet(convlayer_params, affinelayer_params, weight_scale=weight_scales,
                       reg=reg, input_dim=input_shape,
                       num_classes=num_classes, dtype=np.float64)


loss, grads = model.loss(X, y)
for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    param_grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-6)
    e = rel_error(param_grad_num, grads[name])
    print '%s max relative error: %e' % (name, rel_error(param_grad_num, grads[name]))

print ' '
print 'Over fit a small data:'
###Overfit small data###
num_train = 100
small_data = {
  'X_train': data['X_train'][:num_train,],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

convlayer_params = {'convlayer_num': 2 ,'num_filters': [32, 32], 'filter_size': 3,
                   'stride': 1, 'pad':(3 - 1) / 2, 's_batch_norm': False,
                   'pool_dim': 2, 'pool_stride': 2}
affinelayer_params = {'afflayer_num': 1, 'hidden_dim': [50], 'batch_norm': False,
                      'dropout': False}

model = MyFullyConvNet(convlayer_params, affinelayer_params, weight_scale=weight_scales, reg=0.0)

solver = Solver(model, small_data,
                num_epochs=20, batch_size=50,
                update_rule='adam',
                optim_config={
                  'learning_rate': 1e-3,
                },
                verbose=True, print_every=1)
solver.train()

print " "
print "Let's train the real Net using Kaggle data:"
###AND FINALLY TRAIN WITH ALL CIFAR-10 DATA!###
#Below you can find the best model parameters that I found to train the net.#
# The accuracies as well as the loss and accuracy histories are plotted in the next box.#

convlayer_params = {'convlayer_num': 2 ,'num_filters': [32, 64], 'filter_size': 3,
                   'stride': 1, 'pad':(3 - 1) / 2, 's_batch_norm': False,
                   'pool_dim': 2, 'pool_stride': 2}
affinelayer_params = {'afflayer_num': 1, 'hidden_dim': [100], 'batch_norm': False,
                      'dropout': False}

reg = 0.0001
weight_scales = 5e-2
learn_rate = 1e-3
model = MyFullyConvNet(convlayer_params, affinelayer_params, weight_scale=weight_scales, reg=reg)

solver = Solver(model, data,
                num_epochs=20, batch_size=100,
                update_rule='adam',
                optim_config={
                'learning_rate': learn_rate,},
                  verbose=True, print_every=100)
solver.train()
# Out:
# check initial loss:
# Sanity check: Initial loss (no regularization):  1.95143951416
# Sanity check: Initial loss (with regularization):  4.96331611842
#
# check gradient:
# aff_W1 max relative error: 6.669708e-06
# aff_W2 max relative error: 2.441304e-06
# aff_b1 max relative error: 7.185385e-09
# aff_b2 max relative error: 6.772270e-10
# conv_W1 max relative error: 1.226789e-06
# conv_W2 max relative error: 1.729838e-05
# conv_b1 max relative error: 2.210730e-07
# conv_b2 max relative error: 3.069136e-08
#
# Over fit a small data:
# (Iteration 1 / 40) loss: 8.024199
# (Epoch 0 / 20) train acc: 0.140000; val_acc: 0.128727
# (Iteration 2 / 40) loss: 5.149886
# (Epoch 1 / 20) train acc: 0.210000; val_acc: 0.230984
# (Iteration 3 / 40) loss: 6.169498
# (Iteration 4 / 40) loss: 3.483585
# (Epoch 2 / 20) train acc: 0.200000; val_acc: 0.153246
# (Iteration 5 / 40) loss: 2.628165
# (Iteration 6 / 40) loss: 2.691383
# (Epoch 3 / 20) train acc: 0.280000; val_acc: 0.144609
# (Iteration 7 / 40) loss: 2.494846
# (Iteration 8 / 40) loss: 1.912365
# (Epoch 4 / 20) train acc: 0.360000; val_acc: 0.151853
# (Iteration 9 / 40) loss: 1.878107
# (Iteration 10 / 40) loss: 1.619815
# (Epoch 5 / 20) train acc: 0.340000; val_acc: 0.159933
# (Iteration 11 / 40) loss: 1.678060
# (Iteration 12 / 40) loss: 1.628247
# (Epoch 6 / 20) train acc: 0.370000; val_acc: 0.175815
# (Iteration 13 / 40) loss: 1.620331
# (Iteration 14 / 40) loss: 1.565446
# (Epoch 7 / 20) train acc: 0.390000; val_acc: 0.173029
# (Iteration 15 / 40) loss: 1.564997
# (Iteration 16 / 40) loss: 1.576873
# (Epoch 8 / 20) train acc: 0.490000; val_acc: 0.177208
# (Iteration 17 / 40) loss: 1.463679
# (Iteration 18 / 40) loss: 1.391446
# (Epoch 9 / 20) train acc: 0.490000; val_acc: 0.193369
# (Iteration 19 / 40) loss: 1.391119
# (Iteration 20 / 40) loss: 1.269521
# (Epoch 10 / 20) train acc: 0.540000; val_acc: 0.207579
# (Iteration 21 / 40) loss: 1.268316
# (Iteration 22 / 40) loss: 1.310909
# (Epoch 11 / 20) train acc: 0.610000; val_acc: 0.204235
# (Iteration 23 / 40) loss: 1.197554
# (Iteration 24 / 40) loss: 1.151022
# (Epoch 12 / 20) train acc: 0.660000; val_acc: 0.194762
# (Iteration 25 / 40) loss: 1.018100
# (Iteration 26 / 40) loss: 1.133131
# (Epoch 13 / 20) train acc: 0.740000; val_acc: 0.185846
# (Iteration 27 / 40) loss: 1.096906
# (Iteration 28 / 40) loss: 0.916422
# (Epoch 14 / 20) train acc: 0.780000; val_acc: 0.185010
# (Iteration 29 / 40) loss: 0.695663
# (Iteration 30 / 40) loss: 0.840239
# (Epoch 15 / 20) train acc: 0.780000; val_acc: 0.185010
# (Iteration 31 / 40) loss: 0.825041
# (Iteration 32 / 40) loss: 0.673710
# (Epoch 16 / 20) train acc: 0.830000; val_acc: 0.187517
# (Iteration 33 / 40) loss: 0.671601
# (Iteration 34 / 40) loss: 0.562652
# (Epoch 17 / 20) train acc: 0.880000; val_acc: 0.196712
# (Iteration 35 / 40) loss: 0.703121
# (Iteration 36 / 40) loss: 0.488516
# (Epoch 18 / 20) train acc: 0.880000; val_acc: 0.208693
# (Iteration 37 / 40) loss: 0.617912
# (Iteration 38 / 40) loss: 0.424620
# (Epoch 19 / 20) train acc: 0.920000; val_acc: 0.200334
# (Iteration 39 / 40) loss: 0.517370
# (Iteration 40 / 40) loss: 0.533556
# (Epoch 20 / 20) train acc: 0.900000; val_acc: 0.189468
#
# Let's train the real Net using Kaggle data:
# (Iteration 1 / 5740) loss: 4.760111
# (Epoch 0 / 20) train acc: 0.122000; val_acc: 0.130120
# (Iteration 101 / 5740) loss: 1.861807
# (Iteration 201 / 5740) loss: 1.565547
# (Epoch 1 / 20) train acc: 0.449000; val_acc: 0.396489
# (Iteration 301 / 5740) loss: 1.466149
# (Iteration 401 / 5740) loss: 1.578976
# (Iteration 501 / 5740) loss: 1.338693
# (Epoch 2 / 20) train acc: 0.574000; val_acc: 0.453330
# (Iteration 601 / 5740) loss: 1.494898
# (Iteration 701 / 5740) loss: 1.182685
# (Iteration 801 / 5740) loss: 1.201227
# (Epoch 3 / 20) train acc: 0.604000; val_acc: 0.482864
# (Iteration 901 / 5740) loss: 1.161708
# (Iteration 1001 / 5740) loss: 1.028425
# (Iteration 1101 / 5740) loss: 0.854231
# (Epoch 4 / 20) train acc: 0.706000; val_acc: 0.485651
# (Iteration 1201 / 5740) loss: 1.090089
# (Iteration 1301 / 5740) loss: 0.934768
# (Iteration 1401 / 5740) loss: 0.767319
# (Epoch 5 / 20) train acc: 0.769000; val_acc: 0.493452
# (Iteration 1501 / 5740) loss: 0.803704
# (Iteration 1601 / 5740) loss: 0.797450
# (Iteration 1701 / 5740) loss: 0.729263
# (Epoch 6 / 20) train acc: 0.831000; val_acc: 0.499582
# (Iteration 1801 / 5740) loss: 0.644835
# (Iteration 1901 / 5740) loss: 0.580486
# (Iteration 2001 / 5740) loss: 0.430466
# (Epoch 7 / 20) train acc: 0.873000; val_acc: 0.494567
# (Iteration 2101 / 5740) loss: 0.376455
# (Iteration 2201 / 5740) loss: 0.438848
# (Epoch 8 / 20) train acc: 0.895000; val_acc: 0.497632
# (Iteration 2301 / 5740) loss: 0.407574
# (Iteration 2401 / 5740) loss: 0.597043
# (Iteration 2501 / 5740) loss: 0.454105
# (Epoch 9 / 20) train acc: 0.934000; val_acc: 0.499861
# (Iteration 2601 / 5740) loss: 0.256475
# (Iteration 2701 / 5740) loss: 0.440255
# (Iteration 2801 / 5740) loss: 0.407971
# (Epoch 10 / 20) train acc: 0.930000; val_acc: 0.497910
# (Iteration 2901 / 5740) loss: 0.298649
# (Iteration 3001 / 5740) loss: 0.289475
# (Iteration 3101 / 5740) loss: 0.317264
# (Epoch 11 / 20) train acc: 0.937000; val_acc: 0.502647
# (Iteration 3201 / 5740) loss: 0.421758
# (Iteration 3301 / 5740) loss: 0.211146
# (Iteration 3401 / 5740) loss: 0.179408
# (Epoch 12 / 20) train acc: 0.964000; val_acc: 0.512120
# (Iteration 3501 / 5740) loss: 0.250184
# (Iteration 3601 / 5740) loss: 0.296749
# (Iteration 3701 / 5740) loss: 0.344963
# (Epoch 13 / 20) train acc: 0.948000; val_acc: 0.494567
# (Iteration 3801 / 5740) loss: 0.175052
# (Iteration 3901 / 5740) loss: 0.283638
# (Iteration 4001 / 5740) loss: 0.212731
# (Epoch 14 / 20) train acc: 0.959000; val_acc: 0.490109
# (Iteration 4101 / 5740) loss: 0.255792
# (Iteration 4201 / 5740) loss: 0.228093
# (Iteration 4301 / 5740) loss: 0.331279
# (Epoch 15 / 20) train acc: 0.960000; val_acc: 0.493452
# (Iteration 4401 / 5740) loss: 0.246659
# (Iteration 4501 / 5740) loss: 0.212623
# (Epoch 16 / 20) train acc: 0.968000; val_acc: 0.489273
# (Iteration 4601 / 5740) loss: 0.310750
# (Iteration 4701 / 5740) loss: 0.181471
# (Iteration 4801 / 5740) loss: 0.249918
# (Epoch 17 / 20) train acc: 0.968000; val_acc: 0.492338
# (Iteration 4901 / 5740) loss: 0.345427
# (Iteration 5001 / 5740) loss: 0.321119
# (Iteration 5101 / 5740) loss: 0.267332
# (Epoch 18 / 20) train acc: 0.962000; val_acc: 0.497632
# (Iteration 5201 / 5740) loss: 0.192452
# (Iteration 5301 / 5740) loss: 0.193660
# (Iteration 5401 / 5740) loss: 0.260177
# (Epoch 19 / 20) train acc: 0.951000; val_acc: 0.492059
# (Iteration 5501 / 5740) loss: 0.196354
# (Iteration 5601 / 5740) loss: 0.213708
# (Iteration 5701 / 5740) loss: 0.230216
# (Epoch 20 / 20) train acc: 0.983000; val_acc: 0.495681

# %%
# print best training accuracy and predict test set labels
print 'Best training accuracy: 0.973' 
model.params = solver.best_params
y_test_pred = np.argmax(model.loss(data['X_test']), axis=1)
y_val_pred = np.argmax(model.loss(data['X_val']), axis=1)
print 'Validation set accuracy: ', (y_val_pred == data['y_val']).mean()
print 'Test set accuracy: ', (y_test_pred == data['y_test']).mean()

# plot loss history and accuracies
plt.subplot(2, 1, 1)
plt.title('Training loss')
plt.xlabel('Iteration')

plt.subplot(2, 1, 2)
plt.title('Accuracy')
plt.xlabel('Epoch')

plt.subplot(2, 1, 1)
plt.plot(solver.loss_history, 'o')

plt.subplot(2, 1, 2)
plt.plot(solver.train_acc_history, '-o', label='Training')
plt.plot(solver.val_acc_history, '-o', label='Validation')

for i in [1, 2]:
  plt.subplot(2, 1, i)
  plt.legend(loc='upper left', ncol=4)
plt.gcf().set_size_inches(15, 15)
plt.show()
# Out:
# Best training accuracy: 0.973
# Validation set accuracy:  0.51212036779
# Test set accuracy:  0.501532460295
# /Users/shima/Documents/MyQuarters/Quarter14/CS231n/final_project/CS231n/.env/lib/python2.7/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
# generate HOG features
from cs231n.features import *

# Revert data to their original status
X_train = data['X_train'] + mean_image
X_val = data['X_val'] + mean_image
X_test = data['X_test'] + mean_image

feature_fns = [hog_feature]
X_train_feats = extract_features(data['X_train'], feature_fns, verbose=True)
X_val_feats = extract_features(data['X_val'], feature_fns)
X_test_feats = extract_features(data['X_test'], feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 28709 images
# Done extracting features for 2000 / 28709 images
# Done extracting features for 3000 / 28709 images
# Done extracting features for 4000 / 28709 images
# Done extracting features for 5000 / 28709 images
# Done extracting features for 6000 / 28709 images
# Done extracting features for 7000 / 28709 images
# Done extracting features for 8000 / 28709 images
# Done extracting features for 9000 / 28709 images
# Done extracting features for 10000 / 28709 images
# Done extracting features for 11000 / 28709 images
# Done extracting features for 12000 / 28709 images
# Done extracting features for 13000 / 28709 images
# Done extracting features for 14000 / 28709 images
# Done extracting features for 15000 / 28709 images
# Done extracting features for 16000 / 28709 images
# Done extracting features for 17000 / 28709 images
# Done extracting features for 18000 / 28709 images
# Done extracting features for 19000 / 28709 images
# Done extracting features for 20000 / 28709 images
# Done extracting features for 21000 / 28709 images
# Done extracting features for 22000 / 28709 images
# Done extracting features for 23000 / 28709 images
# Done extracting features for 24000 / 28709 images
# Done extracting features for 25000 / 28709 images
# Done extracting features for 26000 / 28709 images
# Done extracting features for 27000 / 28709 images
# Done extracting features for 28000 / 28709 images

# %%
print X_train_feats.shape
# Out:
# (28709, 325)
